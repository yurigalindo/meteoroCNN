# %% [markdown]
# ## Classificando Meteoros

# %% [markdown]
# Esse script utiliza deep learning para classificar imagens do céu noturno como contendo meteoros e ausente de meteoros. Utilizaremos uma CNN pré treinada no imagenet, com arquitetura resnet 34. A base de dados contém 47 imagens de meteoros e 81 imagens de outros objetos não identificados. As imagens foram capturadas por um software que detecta objetos no céu noturno. O validation set consiste em 30% do total de imagens.

# %% [markdown]
# ## Inicialização

# %%
# Automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# This file contains all the main external libs we'll use
from fastai.imports import *

from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
from sklearn.metrics import confusion_matrix

PATH = "Data/DadosMeteorosLorena/"
sz=224 #Tamanho para o qual as imagens serao convertidas

# %%
exemplo = os.listdir(f'{PATH}valid/Meteoros')[0]
img = plt.imread(f'{PATH}valid/Meteoros/{exemplo}')
plt.imshow(img);

# %% [markdown]
# Exemplo de meteoro

# %%
exemplo = os.listdir(f'{PATH}valid/NotMeteoros')[0]
img = plt.imread(f'{PATH}valid/NotMeteoros/{exemplo}')
plt.imshow(img);

# %% [markdown]
# Exemplo de objeto diferente de meteoro

# %% [markdown]
# ## Primeiro modelo

# %% [markdown]
# Modelo simples para comparação. Apenas a ultima layer é treinada, não realizamos data augmentation, e a learning rate tem um valor padrão

# %%
# Uncomment the below if you need to reset your precomputed activations
# shutil.rmtree(f'{PATH}tmp', ignore_errors=True)

# %%
arch=resnet34
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz))
learn = ConvLearner.pretrained(arch, data, precompute=True)
learn.fit(0.01, 5)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.919732   0.714191   0.621622
#     1      0.859332   0.598541   0.621622
#     2      0.72355    0.482908   0.648649
#     3      0.635738   0.410333   0.810811
#     4      0.578686   0.378291   0.837838
# [array([0.37829]), 0.837837815284729]

# %% [markdown]
# Podemos constatar que o modelo é capaz de generalização, porque o erro do validation set é menor do que o do training set. Em nossos testes, atingimos precisão máxima com 5 epochs de treinamento.

# %% [markdown]
# # Analisando as predições

# %%
# Podemos ver que a classe 0 é Meteoros, e a classe 1 NotMeteoros
data.classes
# Out:
# ['Meteoros', 'NotMeteoros']

# %%
# this gives prediction for validation set. Predictions are in log scale
log_preds = learn.predict()
preds = np.argmax(log_preds, axis=1)  # from log probabilities to 0 or 1
probs = np.exp(log_preds[:,1])        # pr(dog)

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 3, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plot_val_with_title(idxs, title):
    imgs = np.stack([data.val_ds[x][0] for x in idxs])
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(data.val_ds.denorm(imgs), rows=1, titles=title_probs)

# %%
def plots(ims, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i])

# %%
def load_img_id(ds, idx): return np.array(PIL.Image.open(PATH+ds.fnames[idx]))

def plot_val_with_title(idxs, title):
    imgs = [load_img_id(data.val_ds,x) for x in idxs]
    title_probs = [probs[x] for x in idxs]
    print(title)
    return plots(imgs, rows=1, titles=title_probs, figsize=(16,8))

# %%
def most_by_mask(mask, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if (y==1)==is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct Meteoros")
# Out:
# Most correct Meteoros

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct Not Meteoros")
# Out:
# Most correct Not Meteoros

# %% [markdown]
# Podemos ver uma baixa confiança quando se trata da presença de meteoros, quando comparada a certeza de que é um objeto diferente de um meteoro

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect Meteoros")
# Out:
# Most incorrect Meteoros

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect Not Meteoros")
# Out:
# Most incorrect Not Meteoros

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")
# Out:
# Most uncertain predictions

# %% [markdown]
# ## Learning rate e data augmentation

# %%
data = ImageClassifierData.from_paths(PATH, bs=2, tfms=tfms_from_model(arch, sz)) #reduzindo o batch size para a busca de 
                                                                                            #learning rates
learn = ConvLearner.pretrained(arch, data, precompute=True)
lrf=learn.lr_find() #buscando learning rates
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  76%|███████▌  | 35/46 [00:00<00:00, 317.85it/s, loss=6.1]

# %%
learn.sched.plot()

# %% [markdown]
# 0.01 era afinal uma boa escolha de learning rate

# %%
tfms = tfms_from_model(resnet34, sz, aug_tfms=transforms_side_on, max_zoom=1.05) # Data augmentation com espelhamento
                                                                                         # horizontal mas nao vertical

# %%
def get_augs():
    data = ImageClassifierData.from_paths(PATH, bs=2, tfms=tfms, num_workers=1)
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
ims = np.stack([get_augs() for i in range(6)])

# %%
plots(ims, rows=2)

# %% [markdown]
# As transformações parecem adequadas, com o detalhe que a margem pode aparecer mais para o meio da imagem, rotacionada. Mas o mais importante: o zoom não é grande, preservando a presença do objeto

# %% [markdown]
# ## Modelo Final

# %% [markdown]
# Entre varios modelos testados, o modelo ganhador foi sem data augmentation, com apenas a ultima layer treinada.
#
# O primeiro treinamento usa SGD normal, e o segundo utiliza SGDR para atingir maiores precisões

# %%
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz)) 
learn = ConvLearner.pretrained(arch, data, precompute=True)
learn.fit(0.01, 1)#treinando sem data augmentation
learn.precompute=False
learn.fit(0.01,1.5,cycle_len=2)#treinando com data augmentation e SGDR
learn.unfreeze()
lr=[1e-4,1e-3,1e-2] 
learn.fit(lr,2,cycle_len=2,cycle_mult=2) #treinando todas as layers
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.822196   0.67104    0.621622
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.492      0.604486   0.621622
#     1      0.538487   0.545437   0.675676
#     2      0.545042   0.485573   0.783784
# HBox(children=(IntProgress(value=0, description='Epoch', max=6), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.887423   0.41709    0.810811
#     1      0.787358   0.396207   0.810811
#     2      0.728659   0.414187   0.810811
#     3      0.62678    0.46436    0.810811
#     4      0.564098   0.548305   0.810811
#     5      0.519782   0.620933   0.72973
# [array([0.62093]), 0.7297297120094299]

# %% [markdown]
# ## Analisando os resultados

# %%
log_preds,y = learn.TTA()
probs = np.mean(np.exp(log_preds),0)     
preds = np.argmax(probs, axis=1)
probs = probs[:,1]
cm = confusion_matrix(y, preds)
plot_confusion_matrix(cm, data.classes)
# Out:
# [[10  4]
#  [ 2 21]]

# %%
plot_val_with_title(most_by_correct(0, True), "Most correct Meteoros")

# %%
plot_val_with_title(most_by_correct(1, True), "Most correct Not Meteoros")

# %%
plot_val_with_title(most_by_correct(0, False), "Most incorrect meteoros")
# Out:
# Most incorrect meteoros

# %% [markdown]
# É preocupante a confiança com a qual o modelo julga que não há meteoros nessas imagens.
#
# Nuvens parecem confundir o modelo, e olhando os dados foi possível perceber que há uma disparidade significante na presença de nuvens. Há uma predominância de nuvens nas fotos em que não há meteoros, e pouquissimas fotos em que temos nuvens e um meteoro.
#
# Essa falha aponta para um problema de generalização presento no modelo. Apesar de ele se sair muito bem nos dados em que utilizamos, ele está explorando uma questão particular da base de dados: a presença de nuvens

# %%
plot_val_with_title(most_by_correct(1, False), "Most incorrect Not Meteoros")

# %%
most_uncertain = np.argsort(np.abs(probs -0.5))[:4]
plot_val_with_title(most_uncertain, "Most uncertain predictions")
